# %% [markdown]
# - Gradient Descent is an optimization algorithm which helps to find optimal weights for your model.
# - It tries to find the weights which fit the models best i.e. minimizes the cost function.
# - Cost function is the difference between actual output and predicted output.
#
# cost function, 𝑦=𝛽+θnXn
# x is parameter
# 𝛽 is the bais
# θ is the weight
#
# - Learning rate, α, is the size of step taken by each gradient.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# y = (x+3)**2
# slope = 2*(x+3)

slope = lambda x : 2*(x+3)

# %%
x = 2
learning_rate = 0.01
precision = 0.000001
max_it = 500

prev_step_size = 1
it = 0

# %%
while prev_step_size > precision and it < max_it:
    prev_x = x
    x = x - learning_rate*slope(x)
    
    prev_step_size = abs(x-prev_x)
    
    it = it+1
    print ("it: ", it, "-", x)
# Out:
# it:  1 - 1.9
# it:  2 - 1.8019999999999998
# it:  3 - 1.70596
# it:  4 - 1.6118408
# it:  5 - 1.519603984
# it:  6 - 1.42921190432
# it:  7 - 1.3406276662336
# it:  8 - 1.253815112908928
# it:  9 - 1.1687388106507495
# it:  10 - 1.0853640344377344
# it:  11 - 1.0036567537489798
# it:  12 - 0.9235836186740002
# it:  13 - 0.8451119463005202
# it:  14 - 0.7682097073745098
# it:  15 - 0.6928455132270196
# it:  16 - 0.6189886029624792
# it:  17 - 0.5466088309032295
# it:  18 - 0.4756766542851649
# it:  19 - 0.40616312119946163
# it:  20 - 0.3380398587754724
# it:  21 - 0.27127906159996296
# it:  22 - 0.2058534803679637
# it:  23 - 0.14173641076060442
# it:  24 - 0.07890168254539233
# it:  25 - 0.017323648894484484
# it:  26 - -0.04302282408340521
# it:  27 - -0.10216236760173711
# it:  28 - -0.16011912024970237
# it:  29 - -0.21691673784470833
# it:  30 - -0.27257840308781417
# it:  31 - -0.3271268350260579
# it:  32 - -0.38058429832553675
# it:  33 - -0.432972612359026
# ...

# %%
print("Local Min: ", x)
# Out:
# Local Min:  -2.9997948800742726
